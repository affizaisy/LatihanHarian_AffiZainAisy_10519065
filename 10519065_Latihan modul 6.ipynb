# %%
import matplotlib.pyplot as plt 
flavors = ('hijau', 'Merah', 'Biru', 'Kuning', 'pink') 
votes = (12, 11, 4, 8, 7) 
colors = ('#8B4513', '#FFF8DC', '#93C572', '#E67F0D', '#D53032') 
explode = (0, 0, 0, 0.1, 0) 
plt.pie( votes, labels=flavors, autopct='%1.1f%%', colors=colors, explode=explode, ) 
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
countries = ('Bandung', 'Medan', 'Jakarta', 'Bekasi', 'Bogor', 'Padang', 'Cilacap', 'Subang', 'Sumedang', 'Tambun', 'Cikarang', 'Cikampek', 'Kerawang', 'Jogja') 
populations = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085, 3481, 287750, 785409, 7107305, 32880332, 585169, 3470475, 28258770) 
x_coords = np.arange(len(countries)) 
plt.bar(x_coords, populations) 
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
countries = ('Bandung', 'Medan', 'Jakarta', 'Bekasi', 'Bogor', 'Padang', 'Cilacap', 'Subang', 'Sumedang', 'Tambun', 'Cikarang', 'Cikampek', 'Kerawang', 'Jogja') 
populations = (450761704, 11661410, 2121757, 19109629, 50819826, 17579085, 3423281, 287752320, 78523409, 71073205, 328803232, 5852169, 3470475, 28258770) 
df = pd.DataFrame({ 'Country': countries, 'Population': populations, }) 
df.sort_values(by='Population', inplace=True) 
x_coords = np.arange(len(df)) 
plt.bar(x_coords, df['Population'], tick_label=df['Country']) 
plt.xticks(rotation=90) 
plt.ylabel('Population (Millions)') 
plt.title('Indonesia Ceria') 
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
countries = ('Bandung', 'Medan', 'Jakarta', 'Bekasi', 'Bogor', 'Padang', 'Cilacap', 'Subang', 'Sumedang', 'Tambun', 'Cikarang', 'Cikampek', 'Kerawang', 'Jogja') 
populations = (45076704, 11626410, 22757, 1232229, 2323226, 172323085, 3422281, 2827750, 7852409, 72233205, 328820332, 23585169, 347230475, 28258770) 
df = pd.DataFrame({ 'Country': countries, 'Population': populations, }) 
df.sort_values(by='Population', inplace=True) 
x_coords = np.arange(len(df)) 
colors = ['#0000FF' for _ in range(len(df))] 
colors[-2] = '#FF0000' 
plt.bar(x_coords, df['Population'], tick_label=df['Country'], color=colors) 
plt.xticks(rotation=90) 
plt.ylabel('Population (Millions)') 
plt.title('South American Populations') 
plt.show()

# %%
temperature_c = [3, 1, 1, 3, 7, 4, 6, 5, 7, 4, 3, 1, 4] 
hour = [0, 2, 4, 6, 8, 10, 12, 12, 13, 16, 19, 28, 27] 
plt.plot( hour, temperature_c ) 
plt.show()

# %%
import matplotlib.pyplot as plt 
temperature_c_actual = [3, 1, 1, 3, 7, 4, 6, 5, 7, 4, 3, 1, 4] 
temperature_c_predicted = [2, 1, 1, 2, 5, 3, 4, 3, 5, 2, 1, 1, 2] 
hour = [0, 2, 4, 6, 8, 10, 12, 12, 13, 16, 19, 28, 27] 
plt.plot(hour, temperature_c_actual)
plt.plot(hour, temperature_c_predicted, linestyle='--') 
plt.title('Temperatures Bandung, Dago , IND on 25 Des 2022') 
plt.ylabel('Temperature Celsius') 
plt.xlabel('Hour') 
plt.show()

# %%
import seaborn as sns 
cities = ['Bandung', 'Cimahi', 'Bekasi', 'Jakarta', 'Dago', 'Lembang', 'Kebun Jeruk', 'Bogor', 'Jogja', 'Palembang', 'Mojokerto', 'Surabaya']
months = ['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'] 
temperatures = [ [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13], 
                # Bandung
                 [14, 14, 10, 17, 10, 19, 15, 14, 14, 13, 18, 12], 
                # Cimahi 
                 [ 28, 20, 24, 20, 24, 28, 22, 22, 27, 23, 27, 21],
                # Bekasi
                 [39, 29, 18, 37, 23, 13, 33, 25, 15, 36, 27, 18],
                # Jakarta 
                 [35, 35, 35, 36, 36, 35, 36, 36, 35, 34, 35, 34], 
                # Dago 
                 [22, 24, 26, 27, 27, 26, 24, 25, 24, 24, 23, 23], 
                # Lembang 
                 [ 2, 5, 12, 21, 27, 30, 31, 30, 26, 19, 10, 4], 
                # Kebun Jeruk
                 [ 9, 10, 14, 20, 25, 28, 32, 33, 29, 23, 18, 12], 
                # Bogor
                 [19, 21, 24, 29, 33, 35, 35, 35, 34, 30, 25, 21], 
                # Jogja
                 [ 4, 6, 11, 18, 22, 27, 29, 29, 25, 18, 13, 7], 
                # Palembang
                 [25, 29, 32, 33, 33, 32, 32, 32, 32, 31, 29, 26], 
                # Mojokerto
                 [26, 28, 32, 35, 36, 35, 33, 32, 33, 35, 32, 28], 
                # Surabaya 
               ]
sns.heatmap(temperatures, yticklabels=cities, xticklabels=months)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
prices = [1422.2, 11858.9, 111467.5, 3241.1, 11559.6, 1073.5, 9304.3, 10402.3, 18762.0, 9874.9, 8547.4, 16938.2, 9905.7, 8004.4, 8923.1, 9352.4, 9853.5, 8459.5, 8245.1, 7361.3, 7646.6, 7515.8, 6505.8, 6167.3, 6398.9, 6765.5, 6254.8, 7408.7, 8234.1, 7014.3, 6231.6, 6379.1, 6734.8, 7189.6, 6184.3, 6519.0, 6729.6, 6603.9, 6596.3, 6321.7, 6572.2, 6494.2, 6386.2, 6427.1, 5621.8, 3920.4, 4196.2, 3430.4, 3228.7, 3964.4, 3706.8, 3785.4, 3597.2, 3677.8, 3570.9, 3502.5, 3661.4, 3616.8, 4120.4, 3823.1, 3944.3, 4006.4, 4002.5, 4111.8, 5046.2, 5051.8, 5290.2, 5265.9, 5830.9, 7190.3, 7262.6, 8027.4, 8545.7, 7901.4, 8812.5, 10721.7, 11906.5, 11268.0, 11364.9, 10826.7, 9492.1, 10815.7, 11314.5, 10218.1, 10131.0, 9594.4, 10461.1, 10337.3, 9993.0, 8208.5, 8127.3, 8304.4, 7957.3, 9230.6, 9300.6, 8804.5, 8497.3, 7324.1, 7546.6, 7510.9, 7080.8, 7156.2, 7321.5, 7376.8]
df = pd.DataFrame(prices)
print(df.max())
print(df.min())
plt.plot(df)
# Out:
# 0    111467.5
# dtype: float64
# 0    1073.5
# dtype: float64
